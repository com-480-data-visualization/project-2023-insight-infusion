# %%
# %pip install pandas
# Out:
# ...
#      ---------------------------------------- 11.3/11.3 MB 8.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.9/14.9 MB 9.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 341.8/341.8 KB 5.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 502.3/502.3 KB 6.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'C:\Users\fauch\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

df_food = pd.read_csv('datasets/products_0.995.csv')
df_food.head()
# Out:
# C:\Users\fauch\AppData\Local\Temp\ipykernel_42596\178375954.py:3: DtypeWarning: Columns (0,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_food = pd.read_csv('datasets/products_0.995.csv')
#                 code                                       product_name
# 0                 50                             Financiers aux Amandes  \
# 1              18166                                  Ultimate Crumpets
# 2         2000006754  Cœur coulant au chocolat - au caramel-beurre salé
# 3  20923301319003905                          Merluza del cabo filletes
# 4              25751                                    Honey roast ham
#
#   abbreviated_product_name                                       generic_name
# 0                      NaN        Pâtisseries fondantes à la poudre d'amande.  \
# 1                      NaN                                                NaN
# 2                      NaN                  fondant au chocolat et au caramel
# ...

# %% [markdown]
# We will now see how many products are in the dataframe df_food

# %%
print('There are ' + str(len(df_food.index)) + ' products in the df_food dataframe')
# Out:
# There are 24469 products in the df_food dataframe

# %% [markdown]
# Now lets see what are the column names of df_food

# %%
col_names = list(df_food)
print(col_names)
# Out:
# ['code', 'product_name', 'abbreviated_product_name', 'generic_name', 'quantity', 'packaging', 'packaging_tags', 'packaging_en', 'packaging_text', 'brands', 'brands_tags', 'categories', 'categories_tags', 'categories_en', 'origins', 'origins_tags', 'origins_en', 'manufacturing_places', 'manufacturing_places_tags', 'labels', 'labels_tags', 'labels_en', 'emb_codes', 'emb_codes_tags', 'first_packaging_code_geo', 'cities', 'cities_tags', 'purchase_places', 'stores', 'countries', 'countries_tags', 'countries_en', 'ingredients_text', 'ingredients_tags', 'ingredients_analysis_tags', 'allergens', 'allergens_en', 'traces', 'traces_tags', 'traces_en', 'serving_size', 'serving_quantity', 'no_nutrition_data', 'additives_n', 'additives', 'additives_tags', 'additives_en', 'nutriscore_score', 'nutriscore_grade', 'nova_group', 'pnns_groups_1', 'pnns_groups_2', 'food_groups', 'food_groups_tags', 'food_groups_en', 'brand_owner', 'ecoscore_score', 'ecoscore_grade', 'nutrient_levels_tags', 'product_quant
# ...
